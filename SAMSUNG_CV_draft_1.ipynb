# %%
import numpy as np

# %%
import torch

# %%
f = torch.nn.Tanh()

# %%
x = torch.tensor([100])
x
# Out:
# tensor([100])

# %%
t1 = f(x)
t2 = f(f(x))
t3 = f(f(f(x)))
t4 = f(f(f(f(x))))

# %%
t1
# Out:
# tensor([1.])

# %%
t2
# Out:
# tensor([0.7616])

# %%
f4 = (1 - t4 ** 2) * t3
f4
# Out:
# tensor([0.4361])

# %%
f3 = (1 - t4 ** 2) * (1 - t3 ** 2) * t2

# %%
f2 = (1 - t4 ** 2) * (1 - t3 ** 2) * (1 - t2 ** 2) * t1

# %%
f1 = (1 - t4 ** 2) * (1 - t3 ** 2) * (1 - t2 ** 2) * (1 - t1 ** 2) * 100

# %%
f1, f2, f3, f4
# Out:
# (tensor([0.]), tensor([0.1677]), tensor([0.3041]), tensor([0.4361]))

# %%
f = torch.nn.ReLU()

# %%
t1 = f(x)
t2 = f(f(x))
t3 = f(f(f(x)))
t4 = f(f(f(f(x))))

# %%
torch.tensor([100]), t1, t2, t3
# Out:
# (tensor([100]), tensor([100]), tensor([100]), tensor([100]))
